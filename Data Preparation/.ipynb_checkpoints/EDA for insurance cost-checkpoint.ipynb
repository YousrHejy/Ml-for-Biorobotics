# %% [markdown]
# ## `Columns Details:`
# - **age**: age of primary beneficiary
# - **sex**: gender: male/female
# - **bmi**: Body mass index
# - **children**: Number of children covered by health insurance / Number of dependents
# - **smoker**: Smoking
# - **region**: the beneficiary's residential area in the US, northeast, southeast, southwest, northwest.
# - **charges**: Individual medical costs decided by health insurance

# %% [markdown]
# ## `Steps to follow:`
# - 1- **Identifying the problem**
# - 2- **Data preparing/preprocessing (if needed)**
# - 3- **EDA for more data understanding**
#
# ------ inside other notebooks (task1_from scrtach,task1_by library)----------
#
# - 4- **Modeling**
# - 5- **Evaluating model**

# %% [markdown]
# ## `First: identifying problem`
# - The main problem we aim to address is to accurately predict insurance costs for individuals
# based on a set of features that describe their personal characteristics and lifestyle choices.

# %%
# importing needed libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("insurance.csv")
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## `Second: Data preparing/preprocessing (if needed) `

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.shape
# Out:
# (1338, 7)

# %%
# checking any missing values
data.isna().any()
# Out:
# age         False
# sex         False
# bmi         False
# children    False
# smoker      False
# region      False
# charges     False
# dtype: bool

# %% [markdown]
# ##### since no missing values needed, let's check the duplication

# %%
#check any duplication my be found
data.duplicated().sum()
# Out:
# 1

# %%
# drop duplication
data.drop_duplicates(inplace=True)

# %%
# Statsical information for numerical features
round(data.describe(include="number"))
# Out:
#           age     bmi  children  charges
# count  1337.0  1337.0    1337.0   1337.0
# mean     39.0    31.0       1.0  13279.0
# std      14.0     6.0       1.0  12110.0
# min      18.0    16.0       0.0   1122.0
# 25%      27.0    26.0       0.0   4746.0
# 50%      39.0    30.0       1.0   9386.0
# 75%      51.0    35.0       2.0  16658.0
# max      64.0    53.0       5.0  63770.0

# %%
# Statsical information for categoral (non-numeric) features
round(data.describe(exclude="number"))
# Out:
#          sex smoker     region
# count   1337   1337       1337
# unique     2      2          4
# top     male     no  southeast
# freq     675   1063        364

# %% [markdown]
# ## `Third: EDA`

# %% [markdown]
# ### Univariante analysis

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data, x="age",binwidth=5, color="blue")
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# ### observation
# - Most of people ages ranges from 18-23

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data, x="bmi",binwidth=5, color="pink")
plt.title("bmi Distribution")
plt.show()

# %% [markdown]
# ### observation
# - Most of people bmi ranges from 26.0-31.0 as their mean is 31.0
# - The above observation declares that most of these people are overweight

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data, y="children", color="green")
plt.title("children Distribution")
plt.show()

# %%
data["children"].value_counts()
# Out:
# 0    573
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %% [markdown]
# ### observation
# - The greater percentage of people dont have children
# - about most of them have only one child
# - the lowest percentage have about 5 children

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data, , color="purple", kda=True)
plt.title("charges Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12800\2004218875.py in <module>
#       1 plt.figure(figsize=(10, 6))
# ----> 2 sns.histplot(data, x="charges", color="purple", kda=True)
#       3 plt.title("charges Distribution")
#       4 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1460     if p.univariate:
#    1461
# -> 1462         p.plot_univariate_histogram(
#    1463             multiple=multiple,
#    1464             element=element,
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     514                         artist = mpl.patches.Rectangle
#     515                         plot_kws = _normalize_kwargs(plot_kws, artist)
# --> 516                         scout = self.ax.fill_between([], [], color=color, **plot_kws)
#     517                         default_color = tuple(scout.get_facecolor().squeeze())
#     518                 else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5243     def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5244                      step=None, **kwargs):
# -> 5245         return self._fill_between_x_or_y(
#    5246             "x", x, y1, y2,
#    5247             where=where, interpolate=interpolate, step=step, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5229             polys.append(pts)
#    5230
# -> 5231         collection = mcoll.PolyCollection(polys, **kwargs)
#    5232
#    5233         # now update the datalim and autoscale
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\collections.py in __init__(self, verts, sizes, closed, **kwargs)
#    1184             Forwarded to `.Collection`.
#    1185         """
# -> 1186         super().__init__(**kwargs)
#    1187         self.set_sizes(sizes)
#    1188         self.set_verts(verts, closed)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     215
#     216         self._path_effects = None
# --> 217         self.update(kwargs)
#     218         self._paths = None
#     219
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'PolyCollection' object has no property 'kda'

# %%
sns.displot(data= data, x="charges", palette= 'icefire', hue= 'region')

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# ### observation
# - The distribution is right-skewed
# - most of people charges range from 1100 to 10000
# - SouthEast is the most percentage that have insurance charges

# %%
sex_count = data["sex"].value_counts()
sex_count
# Out:
# male      675
# female    662
# Name: sex, dtype: int64

# %%
#colors = ['pink', 'lightpink']
colors = ['#FFC0CB', '#FF69B4']
plt.pie(labels=sex_count.index,x=sex_count.values, colors=colors,autopct = '%.2f%%')
plt.title("Distribution of gender")
plt.show()

# %% [markdown]
# ### observation
# - The distribution is slightly equal but men are more

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data, x="smoker", color="salmon")
plt.title("charges Distribution")
plt.show()

# %% [markdown]
# ### observation
# - Most of them don't smoke

# %%
region_count = data["region"].value_counts()
region_count
# Out:
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: region, dtype: int64

# %%
#colors = ['pink', 'lightpink']
colors = ['#FFC0CB', '#FF69B4', '#FF1493', '#FF007F'] 
plt.pie(labels=region_count.index,x=region_count.values, colors=colors,autopct = '%.2f%%')
plt.title("Distribution of gender")
plt.show()

# %% [markdown]
# ### observation
# - The distribution of regions is nearly equal

# %% [markdown]
# ## Bivariante analysis

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data.age, data.charges,hue=data.smoker,palette= ['olive','salmon'] ,alpha=0.6)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data.age, data.charges,hue=data.sex,palette= ['#FFC0CB', '#FF007F'] ,alpha=0.6)
plt.show()
